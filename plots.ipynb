# %%
import plot

# %% [markdown]
# ### IMPALA 100,000 - 3min each - worker

# %%
# training steps 
plot.plot_metric('./results/IMPALA_100000', 'mean_reward', 0, "training steps")
plot.plot_metric('./results/IMPALA_100000', 'mean_reward', 1, "training steps")
plot.plot_metric('./results/IMPALA_100000', 'mean_reward', 2, "training steps")

# %%
plot.plot_metric('./results/IMPALA_100000', 'mean_reward', 0, "time steps")

# %% [markdown]
# ### IMPALA 1m - 20min each - 3 worker

# %%
# training steps 
plot.plot_metric('./results/IMPALA_1m', 'mean_reward', 0, "training steps")
plot.plot_metric('./results/IMPALA_1m', 'mean_reward', 1, "training steps")
plot.plot_metric('./results/IMPALA_1m', 'mean_reward', 2, "training steps")
